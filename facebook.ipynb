# %%
import pandas as pd

# %%
from google.colab import files
files.upload()  # Upload kaggle.json
# Out:
#      <input type="file" id="files-a1862777-faec-4485-b7e4-19e385a99449" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a1862777-faec-4485-b7e4-19e385a99449">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !mkdir -p ~/.kaggle
# !mv kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d masoodanzar/facebook-metrics
# Out:
# Dataset URL: https://www.kaggle.com/datasets/masoodanzar/facebook-metrics
# License(s): unknown

# %%
# !unzip -q facebook-metrics.zip

# %%
import os
os.listdir()
# Out:
# ['.config', 'facebook-metrics.zip', 'dataset_Facebook.csv', 'sample_data']

# %%
df = pd.read_csv("dataset_Facebook.csv", sep=";")
df.head()
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
# Select specific columns
subset_columns = df[['Type', 'Category', 'like', 'share']]

# Select rows where post type is 'Photo'
subset_photo = df[df['Type'] == 'Photo']

# %%
 df_subset_1 = df[['like','share']]
 df_subset_1
# Out:
#        like  share
# 0      79.0   17.0
# 1     130.0   29.0
# 2      66.0   14.0
# 3    1572.0  147.0
# 4     325.0   49.0
# ..      ...    ...
# 495    53.0   26.0
# 496    53.0   22.0
# 497    93.0   18.0
# 498    91.0   38.0
# 499    91.0   28.0
#
# [500 rows x 2 columns]

# %%
df_subset_2 = df[['comment','Type']]
df_subset_2
# Out:
#      comment    Type
# 0          4   Photo
# 1          5  Status
# 2          0   Photo
# 3         58   Photo
# 4         19   Photo
# ..       ...     ...
# 495        5   Photo
# 496        0   Photo
# 497        4   Photo
# 498        7   Photo
# 499        0   Photo
#
# [500 rows x 2 columns]

# %%
 merged_data  = pd.merge(df_subset_2, df_subset_1, left_on='comment',
right_on= 'like')

# %%
merged_data
# Out:
#       comment    Type  like  share
# 0           4   Photo   4.0    2.0
# 1           4   Photo   4.0    1.0
# 2           4   Photo   4.0    0.0
# 3           4   Photo   4.0    1.0
# 4           5  Status   5.0    2.0
# ...       ...     ...   ...    ...
# 1462        0   Photo   0.0    0.0
# 1463        0   Photo   0.0    0.0
# 1464        0   Photo   0.0    0.0
# 1465        0   Photo   0.0    0.0
# 1466        0   Photo   0.0    0.0
#
# [1467 rows x 4 columns]

# %%
 merged_data.sort_values(by=['like'],ascending=False)
# Out:
#       comment   Type   like  share
# 1351      146  Photo  146.0    9.0
# 1352      146  Photo  146.0   15.0
# 550       144  Photo  144.0   29.0
# 549       144  Photo  144.0   10.0
# 712        64  Photo   64.0    7.0
# ...       ...    ...    ...    ...
# 755         0  Photo    0.0    0.0
# 756         0  Photo    0.0    0.0
# 757         0  Photo    0.0    0.0
# 758         0  Photo    0.0    0.0
# 416         0  Photo    0.0    0.0
#
# [1467 rows x 4 columns]

# %%
 merged_data.transpose()
# Out:
#           0      1      2      3       4      5      6      7      8     \
# comment      4      4      4      4       5      0      0      0      0
# Type     Photo  Photo  Photo  Photo  Status  Photo  Photo  Photo  Photo
# like       4.0    4.0    4.0    4.0     5.0    0.0    0.0    0.0    0.0
# share      2.0    1.0    0.0    1.0     2.0    0.0    0.0    0.0    0.0
#
#           9     ...   1457   1458   1459   1460   1461   1462   1463   1464  \
# comment      0  ...      7      7      7      7      7      0      0      0
# Type     Photo  ...  Photo  Photo  Photo  Photo  Photo  Photo  Photo  Photo
# like       0.0  ...    7.0    7.0    7.0    7.0    7.0    0.0    0.0    0.0
# share      0.0  ...    2.0    NaN    2.0    3.0    2.0    0.0    0.0    0.0
#
#           1465   1466
# comment      0      0
# Type     Photo  Photo
# like       0.0    0.0
# share      0.0    0.0
#
# [4 rows x 1467 columns]

# %%
df
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
df.Type.unique()
# Out:
# array(['Photo', 'Status', 'Link', 'Video'], dtype=object)

# %%
pd.melt(df, id_vars=['Type'], value_vars=['comment'])
# Out:
#        Type variable  value
# 0     Photo  comment      4
# 1    Status  comment      5
# 2     Photo  comment      0
# 3     Photo  comment     58
# 4     Photo  comment     19
# ..      ...      ...    ...
# 495   Photo  comment      5
# 496   Photo  comment      0
# 497   Photo  comment      4
# 498   Photo  comment      7
# 499   Photo  comment      0
#
# [500 rows x 3 columns]
